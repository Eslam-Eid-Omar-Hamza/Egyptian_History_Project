# %% [markdown]
# # 🏛 Egyptian Landmarks Detection — Final AI Project
# **Developer:** Eslam Eid Omar Hamza
# **Date:** October 2025
#
# This notebook demonstrates how the trained YOLOv8 model detects famous Egyptian landmarks such as the Pyramids, the Sphinx, and Pharaoh statues.
# The goal is to identify landmarks from images and provide historical information about each one.

# %%
import torch
from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the trained YOLO model
model = YOLO('models/best_giza_landmarks.pt')
print("✅ Model loaded successfully!")
# Out:
# ✅ Model loaded successfully!

# %%
# Test a sample image
image_path = 'assets/Pharaoh_Small1.png'  # replace with an actual test image
results = model(image_path)

# Show results
results[0].show()  # Opens a window with bounding boxes
# Out:
# image 1/1 C:\Users\eslam\Downloads\ \egyptian_landmarks_project\Images\Great Pyramids of Giza.jpg: 640x640 1 Great Pyramids of Giza, 102.6ms
# Speed: 6.1ms preprocess, 102.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Display the image inside the notebook
result_image = results[0].plot()
plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Prediction Result")
plt.show()

# %%
# Optional: Run detection on webcam
# cap = cv2.VideoCapture(0)
# while True:
#     ret, frame = cap.read()
#     results = model(frame)
#     cv2.imshow("Landmark Detection", results[0].plot())
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# ##  Summary
# - **Model Used:** YOLOv8
# - **Dataset:** Egyptian landmarks (Pyramids, Sphinx, Statues, Temples)
# - **Goal:** Automatic detection of landmarks with historical context
# - **Frameworks:** PyTorch, OpenCV, Ultralytics, PyQt5
# - **Result:** The model accurately detects and classifies Egyptian landmarks.
